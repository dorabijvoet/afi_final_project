# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import pandas as pd

# %%
# Replace 'your_file.csv' with the name of your CSV file
df = pd.read_csv('C:\\Users\\yacco\\afi_project_1\\afi_final_project\\predictions_output_gradient_boosting.csv')

# Display the first few rows of the data
df.head()
# Out:
#    Job tenure  Age  Car price  Funding amount  Down payment  Loan duration  \
# 0           2   22       8900            8900             0             60
# 1           0   55      10400            9400             0             72
# 2           1   40      15990           14990             0             60
# 3           5   43      19999           23233             0             72
# 4           1   26      11800            4298             1             24
#
#    Monthly payment  Credit event  Married  Homeowner  Group  Predicted_PD  \
# 0         0.084828             0        0          0      0      0.268061
# 1         0.083889             0        0          0      0      0.350588
# 2         0.127142             0        1          0      0      0.204690
# 3         0.153289             0        0          0      0      0.391570
# 4         0.115528             0        0          0      0      0.109665
#
#    True_Label
# 0           1
# 1           0
# 2           1
# ...

# %%
df_true = df.drop(columns=['True_Label'])

# %%
X = df_true.drop(columns=['Predicted_PD'])  # Features used in the black box model
y_pred = df_true['Predicted_PD']  # Predicted values (lack box model)

# %% [markdown]
# PLTR (somehow standard linear regression works better than Lasso/Ridge, as if when increasing regularization it reduces the R2 factor)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_pred, test_size=0.2, random_state=42)

from sklearn.tree import DecisionTreeRegressor

# Train a decision tree regressor instead of a classifier
tree_model = DecisionTreeRegressor(max_depth=2)
tree_model.fit(X_train, y_train)

# Use the decision tree to transform the data (leaf node predictions)
X_train_leaves = tree_model.apply(X_train)  # Leaf node indices for each sample
X_test_leaves = tree_model.apply(X_test)

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Set up the plot size (adjust as needed)
plt.figure(figsize=(20, 10))

feature_names = X.columns.tolist()

# Plot the tree with decision rules displayed
plot_tree(
    tree_model,
    filled=True,
    feature_names=feature_names,
    rounded=True,
    precision=2,  # Display numerical precision
    proportion=False,  # False means we will show the sample count, not proportion
    fontsize=10,  # Adjust font size for readability
    impurity=True,  # Show impurity (Gini or Entropy)
    class_names=None,
)  # Show class names if available

# Show the plot
plt.show()

# %%
from sklearn.preprocessing import OneHotEncoder

# Convert leaf nodes to categorical features
encoder = OneHotEncoder(sparse=False)
leaf_nodes_train_encoded = encoder.fit_transform(X_train_leaves.reshape(-1, 1))
leaf_nodes_test_encoded = encoder.transform(X_test_leaves.reshape(-1, 1))

from sklearn.linear_model import Lasso, Ridge, LinearRegression

# Train Lasso regression with regularization (L1 penalty)
lasso_model = Lasso(alpha=0.00001)
lasso_model.fit(leaf_nodes_train_encoded, y_train)

ridge_model = Ridge(alpha=0.01)  # You can start with a small alpha
ridge_model.fit(leaf_nodes_train_encoded, y_train)

linear_model = LinearRegression()
linear_model.fit(leaf_nodes_train_encoded, y_train)

# Predict on the test set
y_pred_lasso = lasso_model.predict(leaf_nodes_test_encoded)
y_pred_ridge = ridge_model.predict(leaf_nodes_test_encoded)
y_pred_linear = linear_model.predict(leaf_nodes_test_encoded)
# Out:
# C:\Users\yacco\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Evaluate the model's performance
mse = mean_squared_error(y_test, y_pred_linear)
r2 = r2_score(y_test, y_pred_linear)

print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 0.01780631997744347
# R-squared: 0.35447363129556886

# %% [markdown]
# STANDARD DECISION TREE PREDICTION

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Predict on the test set using the surrogate model
y_pred_surrogate = tree_model.predict(X_test)

# Evaluate the surrogate model performance
mse = mean_squared_error(y_test, y_pred_surrogate)
r2 = r2_score(y_test, y_pred_surrogate)

print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 0.0070081151690219055
# R-squared: 0.7459372210399495

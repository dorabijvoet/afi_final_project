# %% [markdown]
# # Random Forest Classifier

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report
from sklearn.model_selection import GridSearchCV
import os

from sklearn.inspection import partial_dependence
from sklearn.inspection import PartialDependenceDisplay
import matplotlib.pyplot as plt
import seaborn as sns


os.chdir("../data")

# %%
df = pd.read_excel("dataproject2024.xlsx")

# %%
X = df.drop(["Default (y)", "Pred_default (y_hat)", "ID", "PD"], axis=1)
y = df["Default (y)"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
# 1. Define the parameter grid for Random Forest
param_grid_rf = {
    "n_estimators": [100, 200, 300],  # Number of trees in the forest
    "max_depth": [None, 10, 20, 30],  # Maximum depth of the tree
    "min_samples_split": [
        2,
        5,
        10,
    ],  # Minimum number of samples required to split a node
    "min_samples_leaf": [1, 2, 4],  # Minimum number of samples required at a leaf node
    "bootstrap": [True, False],  # Whether bootstrap samples are used
}

# %%
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rf_model.predict(X_test)
y_pred_proba = rf_model.predict_proba(X_test)[:, 1]

# %%
accuracy = accuracy_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred_proba)

# %%
print(f"Accuracy: {accuracy:.4f}")
print(f"AUC-ROC: {roc_auc:.4f}")
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8093
# AUC-ROC: 0.7568
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.95      0.89      1788
#            1       0.54      0.23      0.32       441
#
#     accuracy                           0.81      2229
#    macro avg       0.69      0.59      0.61      2229
# weighted avg       0.78      0.81      0.78      2229

# %%
feature_importances = rf_model.feature_importances_
importance_df = pd.DataFrame(
    {"Feature": X.columns, "Importance": feature_importances}
).sort_values(by="Importance", ascending=False)

print("\nFeature Importances:\n", importance_df)
# Out:
# Feature Importances:
#              Feature  Importance
# 3    Funding amount    0.197999
# 6   Monthly payment    0.187286
# 2         Car price    0.185477
# 1               Age    0.156386
# 0        Job tenure    0.113388
# 5     Loan duration    0.073641
# 9         Homeowner    0.025741
# 8           Married    0.020812
# 10            Group    0.018520
# 7      Credit event    0.012922
# 4      Down payment    0.007829

# %%
result_df = X_test.copy()
result_df["Predicted_PD"] = y_pred_proba
result_df["True_Label"] = y_test.values

print(result_df.head())

result_df.to_csv("predictions_output_random_forest.csv", index=False)
# Out:
#       Job tenure  Age  Car price  Funding amount  Down payment  Loan duration  \
# 625            2   22       8900            8900             0             60
# 2796           0   55      10400            9400             0             72
# 101            1   40      15990           14990             0             60
# 4767           5   43      19999           23233             0             72
# 2018           1   26      11800            4298             1             24
#
#       Monthly payment  Credit event  Married  Homeowner  Group  Predicted_PD  \
# 625          0.084828             0        0          0      0          0.32
# 2796         0.083889             0        0          0      0          0.19
# 101          0.127142             0        1          0      0          0.25
# 4767         0.153289             0        0          0      0          0.26
# 2018         0.115528             0        0          0      0          0.18
#
#       True_Label
# ...

# %% [markdown]
# # Gradient Boosting Classifier

# %%
gb_model = GradientBoostingClassifier(n_estimators=100, random_state=42)
gb_model.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
y_pred = gb_model.predict(X_test)
y_pred_proba = gb_model.predict_proba(X_test)[:, 1]

# %%
accuracy = accuracy_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred_proba)

# %%
print(f"Accuracy: {accuracy:.4f}")
print(f"AUC-ROC: {roc_auc:.4f}")
# Out:
# Accuracy: 0.8170
# AUC-ROC: 0.7684

# %%
result_df = X_test.copy()
result_df["Predicted_PD"] = y_pred_proba
result_df["True_Label"] = y_test.values

print(result_df.head())

result_df.to_csv("predictions_output_gradient_boosting.csv", index=False)
# Out:
#       Job tenure  Age  Car price  Funding amount  Down payment  Loan duration  \
# 625            2   22       8900            8900             0             60
# 2796           0   55      10400            9400             0             72
# 101            1   40      15990           14990             0             60
# 4767           5   43      19999           23233             0             72
# 2018           1   26      11800            4298             1             24
#
#       Monthly payment  Credit event  Married  Homeowner  Group  Predicted_PD  \
# 625          0.084828             0        0          0      0      0.244713
# 2796         0.083889             0        0          0      0      0.327168
# 101          0.127142             0        1          0      0      0.189396
# 4767         0.153289             0        0          0      0      0.391459
# 2018         0.115528             0        0          0      0      0.119370
#
#       True_Label
# ...

# %% [markdown]
# Next steps:
# - Hyperparameter tuning using GridSearchCV to optimize your Random Forest or Gradient Boosting model.
# - Using SHAP (SHapley Additive exPlanations) to interpret your black-box model's predictions.

# %% [markdown]
# # Partial Dependence Plots

# %%
X.columns
# Out:
# Index(['Job tenure', 'Age', 'Car price', 'Funding amount', 'Down payment',
#        'Loan duration', 'Monthly payment', 'Credit event', 'Married',
#        'Homeowner', 'Group'],
#       dtype='object')

# %%
continuous_features = [col for col in X.columns if X[col].nunique() > 10]
categorical_features = [col for col in X.columns if col not in continuous_features]
features_to_plot = X.columns

for feature in features_to_plot:
    fig, ax = plt.subplots(figsize=(8, 6))
    display = PartialDependenceDisplay.from_estimator(rf_model, X_train, [feature], ax=ax)
    plt.title(f'Partial Dependence Plot for {feature}')
    plt.show()

# %%
continuous_features = [col for col in X.columns if X[col].nunique() > 10]  # Arbitrary threshold for continuous features
categorical_features = [col for col in X.columns if col not in continuous_features]
features_to_plot = X.columns

# Determine grid size
n_features = len(features_to_plot)
n_cols = 3  # Number of columns for the grid
n_rows = (n_features // n_cols) + (n_features % n_cols > 0)  # Calculate number of rows needed

# Create a figure for multiple plots
fig, axs = plt.subplots(n_rows, n_cols, figsize=(15, n_rows * 5), constrained_layout=True)
axs = axs.flatten()

for i, feature in enumerate(features_to_plot):
    # Plot for categorical features
    if feature in categorical_features:
        unique_vals = np.sort(X_train[feature].unique())  # Unique categorical values
        pd_display = PartialDependenceDisplay.from_estimator(
            rf_model, X_train, [feature], ax=axs[i], grid_resolution=len(unique_vals), percentiles=(0, 1)
        )
        # pd_values = pd_display.lines_[0][0].get_ydata()
        # axs[i].bar(unique_vals, pd_values, color="skyblue")
        axs[i].set_xticks(unique_vals)
        axs[i].set_ylabel('Predicted PD')
        axs[i].set_title(f'PDP for {feature}')

    # Plot for continuous features
    else:
        pd_display = PartialDependenceDisplay.from_estimator(
            rf_model, X_train, [feature], ax=axs[i], grid_resolution=50
        )
        for line in axs[i].get_lines():
            xs, ys = line.get_data()
            sns.lineplot(xs, ys, ax=axs[i], color="royalblue", lw=2, marker="o", markersize=6)
        axs[i].set_ylabel('Predicted PD')
        axs[i].set_title(f'PDP for {feature}')

# Remove any unused subplots if n_features < n_rows * n_cols
for j in range(i + 1, n_rows * n_cols):
    fig.delaxes(axs[j])

plt.suptitle('Partial Dependence Plots for All Features', fontsize=20)
plt.show()
